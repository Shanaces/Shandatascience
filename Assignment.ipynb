# %% [markdown]
# <a href="https://colab.research.google.com/github/Shanaces/Shandatascience/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
data = pandas.read_csv('https://modcom.co.ke/datasets/Mall_Customers.csv')
data
# Out:
#      CustomerID  Gender  Age  Annual Income  Spending Score
# 0             1    Male   19           15.0            39.0
# 1             2    Male   21           15.0            81.0
# 2             3  Female   20           16.0             6.0
# 3             4  Female   23           16.0            77.0
# 4             5  Female   31           17.0            40.0
# ..          ...     ...  ...            ...             ...
# 195         196  Female   35          120.0            79.0
# 196         197  Female   45          126.0             NaN
# 197         198    Male   32          126.0            74.0
# 198         199    Male   32          137.0            18.0
# 199         200    Male   30          137.0            83.0
#
# [200 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data=data,x='Gender',palette ='Greens')
plt.title('Distribution of gender ')
plt.xlabel('Gender')
plt.ylabel('number of customers')
#There are more female customers in the mall compared to male customers
# Out:
# Text(0, 0.5, 'number of customers')

# %%
data.groupby('Gender').size().plot(kind='pie',autopct='%1.1f%%')
plt.show()
#There are more female customers compared to male customers in the mall

# %%
import numpy
sns.barplot(x='Gender',y='Annual Income',data=data, estimator=numpy.mean, palette = 'magma')
plt.title('Distribution of gender vs annual income')
plt.xlabel('Gender')
plt.ylabel('Annual Income')
#The male annual income is more than the female annual income
# Out:
# Text(0, 0.5, 'Annual Income')
